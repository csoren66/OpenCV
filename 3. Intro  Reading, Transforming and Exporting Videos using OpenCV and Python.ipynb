# %% [markdown]
# # 1.Import dependencies

# %%
#Importing opencv
import cv2

#Importing operating system
import os

#Importing matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# # 2.Setting up captures

# %%
# Setup capture to video 
cap = cv2.VideoCapture(os.path.join('data','videos','Stranger Things 4 _ Volume 1 Final Trailer _ Netflix.mp4'))

# %%
# Grab a frame
ret, frame = cap.read()

# %%
# Render frame 
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Release capture
cap.release()

# %%
cap.read()
# Out:
# (False, None)

# %% [markdown]
# # 3.Capture properties

# %%
# Height
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
# Out:
# 0.0

# %%
# Width
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
# Out:
# 0.0

# %%
# Get number of frames
cap.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# 0.0

# %%
# Frames per second
cap.get(cv2.CAP_PROP_FPS)
# Out:
# 0.0

# %% [markdown]
# # 4.Working with video capture

# %%
# Establish capture
cap = cv2.VideoCapture(os.path.join('data','videos','Stranger Things 4 _ Volume 1 Final Trailer _ Netflix.mp4'))
# Loop through each frame
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    # Read frame 
    ret, frame = cap.read()
    
    # Gray transform
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Show image
    cv2.imshow('Video Player', gray)
    
    # Breaking out of the loop
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Close down everything
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5.Writing out videos

# %%
# Establish capture
cap = cv2.VideoCapture(os.path.join('data','videos','Stranger Things 4 _ Volume 1 Final Trailer _ Netflix.mp4'))

# Properties
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = cap.get(cv2.CAP_PROP_FPS)
# Video Writer 
video_writer = cv2.VideoWriter(os.path.join('data','output','output.avi'), cv2.VideoWriter_fourcc('P','I','M','1'), fps, (width, height), isColor=False) 
                                                                                        
# Loop through each frame
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    # Read frame 
    ret, frame = cap.read()
    
    # Gray transform
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Show image
    cv2.imshow('Video Player', gray)
    
    # Write out frame 
    video_writer.write(gray)
    
    # Breaking out of the loop
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Release video writer
video_writer.release()
